# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    id        f0       f1        f2       f3        f4       f5       f6  \
# 0   0  0.106643  3.59437  132.8040  3.18428  0.081971  1.18859  3.73238
# 1   1  0.125021  1.67336   76.5336  3.37825  0.099400  5.09366  1.27562
# 2   2  0.036330  1.49747  233.5460  2.19435  0.026914  3.12694  5.05687
# 3   3 -0.014077  0.24600  779.9670  1.89064  0.006948  1.53112  2.69800
# 4   4 -0.003259  3.71542  156.1280  2.14772  0.018284  2.09859  4.15492
#
#          f7       f8  ...      f91       f92       f93       f94       f95  \
# 0  2.266270  2.09959  ...  1.09862  0.013331 -0.011715  0.052759  0.065400
# 1 -0.471318  4.54594  ...  3.46017  0.017054  0.124863  0.154064  0.606848
# 2  3.849460  1.80187  ...  4.88300  0.085222  0.032396  0.116092 -0.001688
# 3  4.517330  4.50332  ...  3.47439 -0.017103 -0.008100  0.062013  0.041193
# 4 -0.038236  3.37145  ...  1.91059 -0.042943  0.105616  0.125072  0.037509
#
#         f96      f97       f98       f99  target
# ...

# %%
train = train.drop('id', axis=1)

# %%
train.head()
# Out:
#          f0       f1        f2       f3        f4       f5       f6        f7  \
# 0  0.106643  3.59437  132.8040  3.18428  0.081971  1.18859  3.73238  2.266270
# 1  0.125021  1.67336   76.5336  3.37825  0.099400  5.09366  1.27562 -0.471318
# 2  0.036330  1.49747  233.5460  2.19435  0.026914  3.12694  5.05687  3.849460
# 3 -0.014077  0.24600  779.9670  1.89064  0.006948  1.53112  2.69800  4.517330
# 4 -0.003259  3.71542  156.1280  2.14772  0.018284  2.09859  4.15492 -0.038236
#
#         f8        f9  ...      f91       f92       f93       f94       f95  \
# 0  2.09959  0.012330  ...  1.09862  0.013331 -0.011715  0.052759  0.065400
# 1  4.54594  0.037706  ...  3.46017  0.017054  0.124863  0.154064  0.606848
# 2  1.80187  0.056995  ...  4.88300  0.085222  0.032396  0.116092 -0.001688
# 3  4.50332  0.123494  ...  3.47439 -0.017103 -0.008100  0.062013  0.041193
# 4  3.37145  0.034166  ...  1.91059 -0.042943  0.105616  0.125072  0.037509
#
# ...

# %%
y, X = train['target'], train.drop('target', axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 100 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   f0      600000 non-null  float64
#  1   f1      600000 non-null  float64
#  2   f2      600000 non-null  float64
#  3   f3      600000 non-null  float64
#  4   f4      600000 non-null  float64
#  5   f5      600000 non-null  float64
#  6   f6      600000 non-null  float64
#  7   f7      600000 non-null  float64
#  8   f8      600000 non-null  float64
#  9   f9      600000 non-null  float64
#  10  f10     600000 non-null  float64
#  11  f11     600000 non-null  float64
#  12  f12     600000 non-null  float64
#  13  f13     600000 non-null  float64
#  14  f14     600000 non-null  float64
#  15  f15     600000 non-null  float64
#  16  f16     600000 non-null  float64
#  17  f17     600000 non-null  float64
#  18  f18     600000 non-null  float64
#  19  f19     600000 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corrmat = train.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(102, 102))
g=sns.heatmap(train[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
X.head()
# Out:
#          f0       f1        f2       f3        f4       f5       f6        f7  \
# 0  0.106643  3.59437  132.8040  3.18428  0.081971  1.18859  3.73238  2.266270
# 1  0.125021  1.67336   76.5336  3.37825  0.099400  5.09366  1.27562 -0.471318
# 2  0.036330  1.49747  233.5460  2.19435  0.026914  3.12694  5.05687  3.849460
# 3 -0.014077  0.24600  779.9670  1.89064  0.006948  1.53112  2.69800  4.517330
# 4 -0.003259  3.71542  156.1280  2.14772  0.018284  2.09859  4.15492 -0.038236
#
#         f8        f9  ...       f90      f91       f92       f93       f94  \
# 0  2.09959  0.012330  ...  0.010739  1.09862  0.013331 -0.011715  0.052759
# 1  4.54594  0.037706  ...  0.135838  3.46017  0.017054  0.124863  0.154064
# 2  1.80187  0.056995  ...  0.117310  4.88300  0.085222  0.032396  0.116092
# 3  4.50332  0.123494  ... -0.015347  3.47439 -0.017103 -0.008100  0.062013
# 4  3.37145  0.034166  ...  0.013781  1.91059 -0.042943  0.105616  0.125072
#
# ...

# %%
X.drop(["f0", "f6", "f12", "f13", "f18", "f29", "f38", "f39", "f46", "f52", "f59", "f63", "f65", "f72", "f73", "f74", "f79", "f85", "f86", "f87", "f89", "f92", "f93"], axis=1, inplace=True)

# %%
X.head()
# Out:
#         f1        f2       f3        f4       f5        f7       f8        f9  \
# 0  3.59437  132.8040  3.18428  0.081971  1.18859  2.266270  2.09959  0.012330
# 1  1.67336   76.5336  3.37825  0.099400  5.09366 -0.471318  4.54594  0.037706
# 2  1.49747  233.5460  2.19435  0.026914  3.12694  3.849460  1.80187  0.056995
# 3  0.24600  779.9670  1.89064  0.006948  1.53112  4.517330  4.50332  0.123494
# 4  3.71542  156.1280  2.14772  0.018284  2.09859 -0.038236  3.37145  0.034166
#
#         f10       f11  ...       f84       f88       f90      f91       f94  \
# 0  1.607190 -0.318058  ... -0.015472 -0.118814  0.010739  1.09862  0.052759
# 1  0.331749  0.325091  ...  0.178701  0.121381  0.135838  3.46017  0.154064
# 2  0.328684  2.968810  ... -0.016566  0.979808  0.117310  4.88300  0.116092
# 3  1.002680  4.869600  ... -0.163204  4.917990 -0.015347  3.47439  0.062013
# 4  0.711483  0.769988  ...  0.011234  0.375731  0.013781  1.91059  0.125072
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier(random_state=42)

# %%
forest_clf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
test.head()
# Out:
#        id        f0        f1       f2        f3        f4        f5  \
# 0  600000  0.003229  4.838660  585.529  2.282910  0.713180  3.907830
# 1  600001  0.008602  0.505536 -100.099  3.012670  0.027199  1.194610
# 2  600002  1.461000  2.437260 -112.964  3.541230  0.752338  4.338310
# 3  600003  0.140556  3.085610  179.451  0.573945  0.057342  2.216790
# 4  600004  0.128876  5.199760  107.466 -0.497149  0.080220  0.458121
#
#          f6        f7        f8  ...       f90       f91       f92       f93  \
# 0  0.480696  1.482270  4.891810  ...  0.112910  1.073550  0.122149  0.086330
# 1  5.036620  2.517440  4.553890  ... -0.020214  2.622340  0.123307  0.033063
# 2  1.648080  4.699910  1.950250  ... -0.011036  2.030180 -0.000426  0.084091
# 3  1.623480  0.526174  1.542540  ...  0.050117  0.221613  0.045298  0.129966
# 4  0.629839  5.240460 -0.232279  ...  0.058860  2.660430  0.135425  0.036481
#
#         f94       f95       f96       f97       f98       f99
# ...

# %%
test.drop(["id", "f0", "f6", "f12", "f13", "f18", "f29", "f38", "f39", "f46", "f52", "f59", "f63", "f65", "f72", "f73", "f74", "f79", "f85", "f86", "f87", "f89", "f92", "f93"], axis=True, inplace=True)

# %%
test.head()
# Out:
#          f1       f2        f3        f4        f5        f7        f8  \
# 0  4.838660  585.529  2.282910  0.713180  3.907830  1.482270  4.891810
# 1  0.505536 -100.099  3.012670  0.027199  1.194610  2.517440  4.553890
# 2  2.437260 -112.964  3.541230  0.752338  4.338310  4.699910  1.950250
# 3  3.085610  179.451  0.573945  0.057342  2.216790  0.526174  1.542540
# 4  5.199760  107.466 -0.497149  0.080220  0.458121  5.240460 -0.232279
#
#          f9       f10       f11  ...       f84       f88       f90       f91  \
# 0  0.056351  4.200990  3.151800  ... -0.099653  0.773543  0.112910  1.073550
# 1  0.063876  0.337257  4.439690  ...  0.067636  0.263423 -0.020214  2.622340
# 2  0.005303  2.071680  0.546499  ...  0.446993  0.212414 -0.011036  2.030180
# 3 -0.026160  1.609440  1.723560  ... -0.206052  1.031180  0.050117  0.221613
# 4  0.030006  0.481359  2.176020  ...  0.445268  0.117148  0.058860  2.660430
#
#         f94       f95       f96       f97       f98       f99
# ...

# %%
import tensorflow as tf
import keras

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(77,)),
    keras.layers.Dense(3846, activation=tf.nn.relu),
    keras.layers.Dense(3846, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.fit(X, y, epochs=2, batch_size=1)
test_loss, test_acc = model.evaluate(X, y)
# Out:
# Epoch 1/2
#   1684/600000 [..............................] - ETA: 17:21:26 - loss: 1.0394 - accuracy: 0.5119
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-0dac06f4fb7a> in <module>
#       3              metrics=['accuracy'])
#       4
# ----> 5 model.fit(X, y, epochs=2, batch_size=1)
#       6 test_loss, test_acc = model.evaluate(X, y)
#
# ~/.local/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
from sklearn.neural_network import MLPClassifier

mlp_clf = MLPClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier

knc_clf = KNeighborsClassifier()

# %%
knc_clf.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
prediction = knc_clf.predict(test)

# %%
sub = pd.read_csv('submission.csv')

# %%
sub.head()
# Out:
#        id  target
# 0  600000       1
# 1  600001       1
# 2  600002       1
# 3  600003       1
# 4  600004       0

# %%
sub['target'] = prediction

# %%
sub.head()
# Out:
#        id  target
# 0  600000       1
# 1  600001       1
# 2  600002       1
# 3  600003       1
# 4  600004       1

# %%
sub.to_csv('submission.csv', index=False)
